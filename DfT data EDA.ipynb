# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import geopandas as gpd

# %%
data = pd.read_csv('cleaned_dft_statistics_collision_and_casualty_last_5_years.csv', low_memory = False)
data = data.copy()

# %%
sorter = ['0 - 5', '6 - 10', '11 - 15', '16 - 20', '21 - 25', '26 - 35', '36 - 45', '46 - 55', '56 - 65', '66 - 75', 'Over 75']
data.groupby(['age_band_of_casualty', 'sex_of_casualty']).size().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='age_band_of_casualty'>
